# %% [markdown]
# # Wikidocs - Tutorial

# %%
# import
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 한글사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# ### 01. Matplotlib 기본 사용

# %%
plt.plot([1, 3, 2, 4])
plt.ylabel('y-label')
plt.show()

# %% [markdown]
# ### 스타일 지정하기

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # 'r'은 red를 뜻하고 'o'는 동그란 점을 의미
plt.axis([0, 6, 0, 20])
plt.show()
# color: blue, green, red, cyan, magenta, yellow, black(k), white
# marker: circle(o), 삼각형(^), 역삼각형(v), 사각형(s), 별(*), 플러스(+)
# linestyle: 직선(-), dashed(--), dash-dot(-.), dotted(:)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'cs-')
#  axis()를 이용해서 축의 범위 [xmin, xmax, ymin, ymax]
plt.axis([0, 6, 0, 20])
plt.show()

# %%
t = np.arange(0., 5., 0.2)

# 빨간 대쉬, 파란 사각형, 녹색 삼각형
        #[x] [y] 옵션 순으로 추가
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
t = np.arange(0., 5., 0.02)
        #[x] [y] 옵션 순으로 추가
plt.plot(t, t, 'r-', t, t**2, 'b-', t, t**3, 'g-')
plt.show()

# %% [markdown]
# ### Matplotlib 축 레이블 설정하기

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# plt.xlabel x이름붙이기 y도 마찬가지
plt.xlabel('X-레이블'); plt.ylabel('Y-레이블')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
#  axis()를 이용해서 축의 범위 [xmin, xmax, ymin, ymax]
plt.axis([0, 5, 0, 20])  # 반드시 4개 다 입력해야함
plt.show()

# %% [markdown]
# #### Matplotlib 색상 지정하기

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], color='springgreen', linewidth = 20) # color로 색 지정 , linewidth로 굵기 조정
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.axis([0, 5, 0, 20])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
               #x[1]~[2]과 y[1]~[2]를 채움    알파는 투명도
plt.fill_between(x[1:3], y[1:3], alpha=0.5)                   ## fill_between() 사용
plt.fill_betweenx(y[2:4], x[2:4], color='pink', alpha=0.5)  ## fill_betweenx() 사용
plt.axhline(1) # x축 라인 생성 디폴트는 0
plt.axvline(1) #y축 라인 생성  디폴트는 역시 0
plt.show()

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
# 네 점(x[1], y[1]), (x[1], y[2]), (x[2], y[1]), (x[2], y[2]) 사이 영역을 채움
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)

plt.show()

# %%
# 곡선으로 보이게하기
x = np.arange(1.0,4.0,0.01)
y1 = x **2
y2 = x **2 /2
plt.title('두 그래프 사이 영역 채우기') # 타이틀 지정
plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.fill_between(x[100:200], y1[100:200], y2[100:200], color='lightgray', alpha=0.5)

plt.show()

# %%
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
# 원하는 x,y값을 리스트에 입력하면 더 쉽게 채울 수 있다.
plt.fill([1.9, 1.9, 3.1, 3.1], [2, 5, 11, 8], color='lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# #### 여러 곡선 그리기

# %%
a = np.arange(0, 2, 0.2)
            # 빨간 -- , 파란 점 , 녹색 점선
plt.plot(a, a, 'r--', a, a**2, 'bo', a, a**3, 'g-.')
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo') # 파란점 
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2) # css로 색 지정, *점, 선굵기 2
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
# 색 스프링그린, 삼각형, 점(삼각형)크기 9
plt.show()

# %% [markdown]
# #### Matplotlib 그리드 설정하기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.grid(True) # 이거만 하면 배경을 표처럼 바꿀 수 있음

plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y') # y축만 사용 x,y,both 세가지를 쓸 수있는데 디폴트(빈 칸 일때) both

plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')
# 그리드도 스타일 설정 가능
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
# x축에 나오는 숫자들을 xticks라고 하나봄 이걸로 지정가능
plt.yticks(np.arange(1, 6))

plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
# x눈금에 이름붙이기
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
# y눈금에 이름붙이기
plt.show()

# %% [markdown]
# ### Matplotlib 타이틀 설정하기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='gray', alpha=0.5, linestyle='--')
plt.tick_params(axis='both', direction='in', length=3, pad=10, labelsize=14)
# direction='in' 눈금을 안으로 지정 in,out,inout이 있음length는 눈금의 길이를 지정 pad는 눈금과 레이블과의 거리,labelsize는 레이블의 크기를 지정
plt.title('Sample graph', loc='right', pad=20) #제목 오른쪽위로옮기기
plt.show()

# %%
# 폰트 설정하고 입력하기
plt.title('Sample graph', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
plt.title('Sample graph', fontdict=title_font, loc='left', pad=20)
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='gray', alpha=0.5, linestyle='--')
plt.tick_params(axis='both', direction='in', length=3, pad=10, labelsize=14)

# %% [markdown]
# #### Matplotlib 수직선/수평선 표시하기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.axhline(1, 0, 0.55, color='gray', linestyle='--', linewidth='1')
plt.axvline(1, 0, 0.16, color='lightgray', linestyle=':', linewidth='2')
plt.axhline(5.83, 0, 0.95, color='gray', linestyle='--', linewidth='1')
#
plt.axvline(1.8, 0, 0.95, color='lightgray', linestyle=':', linewidth='2')

plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.hlines(4, 1, 1.6, colors='pink', linewidth=3)
plt.vlines(1, 1, 4, colors='pink', linewidth=3)

plt.show()

# %%
x = np.linspace(0,2*np.pi, 256)
s = np.sin(x)
c = np.cos(x)
plt.plot(x, s, label='Sine')
plt.plot(x, c, label='Cosine')
plt.title('사인, 코사인 그래프', loc='center', pad=10)
plt.grid(True)
plt.xticks([0, np.pi/2, np.pi, 3*np.pi/2, 2*np.pi], labels=['0', '1/2π', 'π', '2/3π', '2π'])
plt.yticks([-1,0,1])
plt.axhline(1, color='gray', linestyle='--')
plt.axhline(-1, color='gray', linestyle='--')
plt.axvline(np.pi, color='gray', linestyle='--')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### Matplotlib 막대 그래프 그리기

# %%
x = np.arange(3)
years = ['2017', '2018', '2019']
values = [100, 400, 900]

plt.bar(x, values) #plot -> bar
plt.xticks(x, years)
plt.show()

# %%
x = np.arange(3)
years = ['2017', '2018', '2019']
values = [100, 400, 900]
plt.title('스타일 꾸미기')
plt.bar(x, values, width=0.6, align='edge', color="springgreen",
        edgecolor="gray", linewidth=3, tick_label=years, log=True)
        # log=True로 설정하면, y축이 로그, tick_label로 문자열 순서대로 나옴 align는 막대위치 디폴트는 센터
plt.show()

# %%
y = np.arange(3)
years = ['2017', '2018', '2019']
values = [100, 400, 900]

plt.barh(y, values, height=-0.6, align='edge', color="springgreen",
        edgecolor="gray", linewidth=3, tick_label=years, log=False)
plt.show()

# %% [markdown]
# #### Matplotlib 산점도 그리기

# %%
np.random.seed(2020)    # Reproducible random state

N = 50
x = np.random.rand(N)
y = np.random.rand(N)

plt.scatter(x, y)
plt.show()

# %%
np.random.seed(2020)    # Reproducible random state

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
x = iris[iris.species == 'setosa'].sepal_length
y = iris[iris.species == 'setosa'].sepal_width
plt.title('iris')
plt.scatter(x, y)
plt.xlabel('sepal_length')
plt.ylabel('sepal_length')
plt.show()

# %% [markdown]
# #### 18. Matplotlib 히스토그램 그리기

# %%
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71, 80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight)
plt.show()

# %%
np.random.seed(2020)
x = np.random.randn(10000)
plt.hist(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
np.random.seed(2020)
x = np.random.randn(100000)
plt.hist(x, bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = np.linspace(-4.0,4.0,801)
nd = np.exp(-x*x/2) / np.sqrt(2*np.pi)
plt.plot(x, nd)
plt.axhline(0, alpha =0.5); plt.axvline(0, alpha = 0.5)
plt.show()

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.rand(5000) - 10.0

plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step', label='a')
plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled', label='b')
# histtype='stepfilled' 막대 채우기 , step 은비우기
plt.hist(c, bins=100, density=True, alpha=0.9, histtype='step', label='c')
# bins 는 쪼개는 갯수
plt.legend()
plt.show()

# %% [markdown]
# #### Matplotlib 파이 차트 그리기

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
# 반 시계 방향
plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False)
# counterclock=False 시계 방향으로 돌리기, startangle=260 시작각도 디폴트는 0
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0, 0.10, 0, 0.10]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode)
plt.show()

# %%
x = iris[iris.species == 'setosa'].sepal_length
y = iris[iris.species == 'setosa'].sepal_width
z = iris[iris.species == 'setosa'].petal_length
v = iris[iris.species == 'setosa'].petal_width
plt.title('iris_setosa')
plt.boxplot([x,y,z,v], labels=['sepal_length','sepal_width','petal_length','petal_width'])
plt.show()

# %%
x = iris[iris.species == 'versicolor'].sepal_length
y = iris[iris.species == 'versicolor'].sepal_width
z = iris[iris.species == 'versicolor'].petal_length
v = iris[iris.species == 'versicolor'].petal_width
plt.title('iris_versicolor')
plt.boxplot([x,y,z,v], labels=['sepal_length','sepal_width','petal_length','petal_width'])
plt.show()

# %%
x = iris[iris.species == 'virginica'].sepal_length
y = iris[iris.species == 'virginica'].sepal_width
z = iris[iris.species == 'virginica'].petal_length
v = iris[iris.species == 'virginica'].petal_width
plt.title('iris_virginica')
plt.boxplot([x,y,z,v], labels=['sepal_length','sepal_width','petal_length','petal_width'])
plt.show()

# %%
iris = sns.load_dataset('iris')
ds1 = iris[iris.species == 'setosa']
ds2 = iris[iris.species == 'versicolor']
ds3 = iris[iris.species == 'virginica']
fig = plt.figure()
axes1 = fig.add_subplot(3, 1, 1); axes2 = fig.add_subplot(3,1,2)
axes3 = fig.add_subplot(3, 1, 3)
axes1.boxplot(ds1['sepal_length'], ds1['sepal_width'],ds1['petal_length'],ds1['petal_width'])
axes2.boxplot(ds2['sepal_length'], ds2['sepal_width'],ds2['petal_length'],ds2['petal_width'])
axes3.boxplot(ds3['sepal_length'], ds3['sepal_width'],ds3['petal_length'],ds3['petal_width'])
axes1.set_title('setosa'); axes2.set_title('versicolor')
axes3.set_title('virginica')
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-2467bd3c7587> in <module>
#       6 axes1 = fig.add_subplot(3, 1, 1); axes2 = fig.add_subplot(3,1,2)
#       7 axes3 = fig.add_subplot(3, 1, 3)
# ----> 8 axes1.boxplot(ds1['sepal_length'], ds1['sepal_width'])
#       9 axes2.boxplot(ds2['sepal_length'], ds2['sepal_width'],ds2['petal_length'],ds2['petal_width'])
#      10 axes3.boxplot(ds3['sepal_length'], ds3['sepal_width'],ds3['petal_length'],ds3['petal_width'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     294                 f"for the old name will be dropped %(removal)s.")
#     295             kwargs[new] = kwargs.pop(old)
# --> 296         return func(*args, **kwargs)
#     297
#     298     # wrapper() must keep the same documented signature as func(): if we
#
# ...

# %%
ds1
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
ds1
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
x = np.linspace(0, 2 * np.pi, 500)
y1 = np.sin(x)
y2 = np.sin(3 * x)

fig, ax = plt.subplots()
ax.fill(x, y1, 'b', x, y2, 'r', alpha=0.3)
plt.show()

# %%
x = np.linspace(0, 10, 500)
dashes = [10, 2,100,5]  # 10 points on, 5 off, 100 on, 5 off

fig, ax = plt.subplots()
line1, = ax.plot(x, np.sin(x), '--', linewidth=2,
                 label='Dashes set retroactively')
line1.set_dashes(dashes)

line2, = ax.plot(x, -1 * np.sin(x),
                 label='Dashes set proactively')
dashes2 = [30, 5, 10, 5]                 
line2.set_dashes(dashes2)
ax.legend(loc='lower right')
plt.show()

# %%
x = np.arange(0.1, 4, 0.5)
y = np.exp(-x)

fig, ax = plt.subplots()
ax.errorbar(x, y, xerr=0.2, yerr=0.4)
plt.show()

# %%
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, projection='polar')
bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.viridis(r / 10.))
    bar.set_alpha(0.5)

plt.show()

# %%
ans = sns.load_dataset('anscombe')
ans.shape; ans.head(); ans.tail()
ans.groupby('dataset').describe()
# Out:
# (44, 3)

# %%
ds1 = ans[ans['dataset'] == 'I']; ds2 = ans[ans['dataset'] == 'II']
ds3 = ans[ans['dataset'] == 'III']; ds4 = ans[ans['dataset'] == 'IV']

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1); axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3); axes4 = fig.add_subplot(2, 2, 4)
axes1.plot(ds1['x'], ds1['y'], 'o'); axes2.plot(ds2['x'], ds2['y'], 'o')
axes3.plot(ds3['x'], ds3['y'], 'o'); axes4.plot(ds4['x'], ds4['y'], 'o')
axes1.set_title('Dataset 1'); axes2.set_title('Dataset 2')
axes3.set_title('Dataset 3'); axes4.set_title('Dataset 4')
fig.suptitle("Anscombe's Quartet")
fig.tight_layout()

# %%
ans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b0e96a6ac391> in <module>
# ----> 1 ans
#
# NameError: name 'ans' is not defined

# %%
def f(t):
 return np.exp(-t) * np.cos(2*np.pi*t)
def g(t):
 return np.sin(np.pi*t)
t1 = np.arange(0.0, 5.0, 0.01)
t2 = np.arange(0.0, 5.0, 0.01)
plt.subplot(221) # 2 x 2, 그래프중 첫번째
plt.plot(t1, f(t1))
plt.subplot(2, 2, 2)
plt.plot(t2, g(t2))
plt.subplot(223)
plt.plot(t1, f(t1), 'r-')
plt.subplot(224)
plt.plot(t2, g(t2), 'r-')
plt.show()

# %%
import math
xs, ysin, ycos = [], [], []
for x in range(360):
    xs.append(x)
    ysin.append(math.sin(math.pi * x / 180))
    ycos.append(math.cos(math.pi * x / 180))
xs = np.arange(0, 2*np.pi, 0.01)
ysin = np.sin(xs); ycos = np.cos(xs)
plt.plot(xs, ysin, label='Sine curve')
plt.plot(xs, ycos, label='Cosine curve')
plt.xlim([0, 2*math.pi]); plt.ylim([-1.2, 1.2])
plt.xlabel('X-Value'); plt.ylabel('Y-Value')
plt.title('삼각함수')
plt.legend(loc='center') # label을 범례로 표시
plt.axhline(y=0, color='k', linewidth=0.5) # 수평선(x축)
plt.axvline(x=0, color='k', linewidth=0.5) # 수직선(y축)
plt.axvline(x=360, color='k', linewidth=0.5)
