# %%
# import
import numpy as np  
import pandas as pd

# %% [markdown]
# ### 연습문제

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")

# %% [markdown]
# #### 연습문제 4.4.7 타이타닉호 승객을 ‘미성년자’, ‘청년’, ‘중년’, ‘장년’, ‘노년’ 나이 그룹으로 나눈다.그리고 각 나이 그룹의 승객 비율을 구한다. 비율의 전체 합은 1이 되어야 한다.

# %%
titanic['age']=titanic['age'].fillna(titanic['age'].mean())
bins = [1, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "중년", "장년", "노년"]
titanic["age_cat"] = pd.cut(titanic.age, bins, labels=labels)
x =titanic.age_cat.value_counts()/titanic.age_cat.value_counts().sum()
x
# Out:
# 청년      0.464082
# 중년      0.274800
# 미성년자    0.188141
# 장년      0.067275
# 노년      0.005701
# Name: age_cat, dtype: float64

# %% [markdown]
# #### 연습문제 4.4.8 타이타닉호의 승객에 대해 나이와 성별에 의한 카테고리 열인 category3 열을 만들어라. category3 카테고리는 다음과 같이 정의된다. 20살 미만이면 성별에 관계없이 “미성년자”라고 한다. 20살 이상이면 나이에 따라 “청년”, “중년”, “장년”, “노년”을 구분하고 그 뒤에 성별을 나타내는 “남성”, “여성”을 붙인다.

# %%
titanic["category3"] = titanic.apply(lambda r: "미성년자" if r.age < 20  else str(r.age_cat) +'남성' if r.sex == 'male' else str(r.age_cat) + '여성' , axis=1)
titanic.tail()
# Out:
#      survived  pclass     sex        age  sibsp  parch   fare embarked  \
# 886         0       2    male  27.000000      0      0  13.00        S
# 887         1       1  female  19.000000      0      0  30.00        S
# 888         0       3  female  29.699118      1      2  23.45        S
# 889         1       1    male  26.000000      0      0  30.00        C
# 890         0       3    male  32.000000      0      0   7.75        Q
#
#       class    who  adult_male deck  embark_town alive  alone age_cat  \
# 886  Second    man        True  NaN  Southampton    no   True      청년
# 887   First  woman       False    B  Southampton   yes   True    미성년자
# 888   Third  woman       False  NaN  Southampton    no  False      청년
# 889   First    man        True    C    Cherbourg   yes   True      청년
# 890   Third    man        True  NaN   Queenstown    no   True      중년
#
#     category3
# 886      청년남성
# 887      미성년자
# 888      청년여성
# 889      청년남성
# 890      중년남성

# %% [markdown]
# ### 1번문제

# %%
x = pd.read_csv('population_age_2020.csv')

# %%
answer1 = x.values.tolist()
answer1
# Out:
# [['서울',
#   9736962,
#   658355,
#   813563,
#   1455903,
#   1505729,
#   1563968,
#   1539385,
#   1200518,
#   688818,
#   263939,
#   40404,
#   6380],
#  ['부산',
#   3410925,
#   241624,
#   281120,
#   434692,
#   431911,
#   518321,
#   580966,
#   511174,
#   285602,
#   109312,
#   14396,
#   1807],
#  ['대구',
#   2432883,
#   186623,
#   234528,
#   321487,
#   303397,
#   391997,
#   428622,
#   311274,
#   171217,
#   74227,
#   8817,
#   694],
#  ['인천',
#   2954955,
#   239941,
#   281097,
#   405835,
#   417708,
#   490716,
#   515758,
#   344843,
#   172269,
#   74306,
#   11574,
#   908],
#  ['광주',
#   1456121,
#   125396,
#   162728,
#   207554,
#   191432,
#   244903,
#   234048,
#   155056,
#   91020,
#   38050,
#   5529,
#   405],
#  ['대전',
#   1473125,
#   120476,
#   151861,
#   212143,
#   199106,
#   242381,
#   243526,
#   170291,
#   88289,
#   39190,
#   5523,
#   339],
#  ['울산',
#   1145710,
#   103399,
#   115623,
#   147745,
#   158271,
#   190698,
# ...

# %%
answer2 = x.T.values.tolist()
answer2
# Out:
# [['서울',
#   '부산',
#   '대구',
#   '인천',
#   '광주',
#   '대전',
#   '울산',
#   '세종',
#   '경기도',
#   '강원도',
#   '충청북도',
#   '충청남도',
#   '전라북도',
#   '전라남도',
#   '경상북도',
#   '경상남도',
#   '제주도'],
#  [9736962,
#   3410925,
#   2432883,
#   2954955,
#   1456121,
#   1473125,
#   1145710,
#   343788,
#   13265377,
#   1539521,
#   1598599,
#   2120995,
#   1815112,
#   1861894,
#   2658956,
#   3358828,
#   670876],
#  [658355,
#   241624,
#   186623,
#   239941,
#   125396,
#   120476,
#   103399,
#   47454,
#   1178548,
#   108694,
#   128290,
#   179808,
#   135297,
#   137868,
#   198214,
#   282751,
#   62086],
#  [813563,
#   281120,
#   234528,
#   281097,
#   162728,
#   151861,
#   115623,
#   40574,
#   1347854,
#   141975,
#   153119,
#   206578,
#   180675,
#   172888,
#   233506,
#   331566,
#   71539],
#  [1455903,
#   434692,
#   321487,
#   405835,
#   207554,
#   212143,
#   147745,
#   36273,
#   1769080,
#   179813,
#   198910,
#   243748,
#   212339,
#   202760,
#   291097,
# ...

# %% [markdown]
# ### 3번문제

# %%
answer3 = x.to_dict('list')
answer3
# Out:
# {'지역': ['서울',
#   '부산',
#   '대구',
#   '인천',
#   '광주',
#   '대전',
#   '울산',
#   '세종',
#   '경기도',
#   '강원도',
#   '충청북도',
#   '충청남도',
#   '전라북도',
#   '전라남도',
#   '경상북도',
#   '경상남도',
#   '제주도'],
#  '총인구수': [9736962,
#   3410925,
#   2432883,
#   2954955,
#   1456121,
#   1473125,
#   1145710,
#   343788,
#   13265377,
#   1539521,
#   1598599,
#   2120995,
#   1815112,
#   1861894,
#   2658956,
#   3358828,
#   670876],
#  '0~9세': [658355,
#   241624,
#   186623,
#   239941,
#   125396,
#   120476,
#   103399,
#   47454,
#   1178548,
#   108694,
#   128290,
#   179808,
#   135297,
#   137868,
#   198214,
#   282751,
#   62086],
#  '10~19세': [813563,
#   281120,
#   234528,
#   281097,
#   162728,
#   151861,
#   115623,
#   40574,
#   1347854,
#   141975,
#   153119,
#   206578,
#   180675,
#   172888,
#   233506,
#   331566,
#   71539],
#  '20~29세': [1455903,
#   434692,
#   321487,
#   405835,
#   207554,
#   212143,
#   147745,
#   36273,
#   1769080,
#   179813,
#   198910,
# ...

# %% [markdown]
# ### 4번문제

# %%
answer4 = pd.DataFrame(answer3)
answer4
# Out:
#       지역      총인구수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 4     광주   1456121   125396   162728   207554   191432   244903   234048
# 5     대전   1473125   120476   151861   212143   199106   242381   243526
# 6     울산   1145710   103399   115623   147745   158271   190698   211255
# 7     세종    343788    47454    40574    36273    61442    65714    42907
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# ...

# %% [markdown]
# ### 5번문제

# %%
answer6=x[['지역','100세 이상','총인구수']].sort_values(by='100세 이상',ascending=False)
answer6.index = range(17)
answer6
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 1    경기도     4010  13265377
# 2     부산     1807   3410925
# 3   경상북도      960   2658956
# 4     인천      908   2954955
# 5   충청남도      885   2120995
# 6   전라남도      822   1861894
# 7   전라북도      817   1815112
# 8    강원도      803   1539521
# 9   경상남도      739   3358828
# 10    대구      694   2432883
# 11  충청북도      541   1598599
# 12    광주      405   1456121
# 13    대전      339   1473125
# 14   제주도      266    670876
# 15    울산      160   1145710
# 16    세종       55    343788
