# %%
# import
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %%
nums_df=pd.read_csv('lotto_nums.csv')

# %%
prize_df = pd.read_csv('lotto_prize.csv')

# %%
nums = nums_df.set_index('회차')
prize = prize_df.set_index('회차')

# %%
del nums['2등번호']

# %%
nums[nums == 1].count().sum()
# Out:
# 131

# %%
dict_tmp = {}
for i in range(1,46):
    nums_sum = nums[nums == i].count().sum()
    dict_tmp[i] = nums_sum

# %%
l_s = pd.Series(dict_tmp)

# %%
a = []
for i in range(1,46):
    a.append(i)

# %%
plt.figure(figsize=(12, 3))
plt.scatter(l_s.index, l_s.values,color="lightseagreen")
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('번호당 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.bar(l_s.index, l_s.values, color = 'lightseagreen')
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('로또 번호당 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.bar(l_s.sort_values(ascending = False).head(10).index, l_s.sort_values(ascending = False).head(10), color = 'lightseagreen')
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(l_s.sort_values(ascending = False).head(10).index)
plt.title('로또 Top 10', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
s_num=pd.read_csv('lotto_nums.csv')

# %%
s_dict =dict(s_num['2등번호'].value_counts())

# %%
s_s = pd.Series(s_dict)

# %%
plt.figure(figsize=(12, 3))
plt.bar(s_s.index, s_s.values, color = 'lightseagreen')
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('로또 2등번호 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.scatter(s_s.index, s_s.values)
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('로또 2등번호 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
n1 = dict(nums['번호1'].value_counts())
n1 = pd.Series(n1)
n2 = dict(nums['번호2'].value_counts())
n2 = pd.Series(n2)
n3 = dict(nums['번호3'].value_counts())
n3 = pd.Series(n3)
n4 = dict(nums['번호4'].value_counts())
n4 = pd.Series(n4)
n5 = dict(nums['번호5'].value_counts())
n5 = pd.Series(n5)
n6 = dict(nums['번호6'].value_counts())
n6 = pd.Series(n6)

# %%
plt.figure(figsize=(12, 3))
plt.scatter(n1.index, n1.values,color="lightseagreen")
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('첫번째 번호 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.scatter(n2.index, n2.values,color="lightseagreen")
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('두번째 번호 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.scatter(n3.index, n3.values,color="lightseagreen")
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('세번째 번호 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.scatter(n4.index, n4.values,color="lightseagreen")
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('네번째 번호 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.scatter(n5.index, n5.values,color="lightseagreen")
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('다섯번째 번호 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(12, 3))
plt.scatter(n6.index, n6.values,color="lightseagreen")
plt.xlabel('당첨 번호')
plt.ylabel('당첨 수')
plt.xticks(a)
plt.title('여섯번째 번호 당첨횟수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
using = [l_s[1:9].sum(),l_s[10:1].sum(),l_s[20:29].sum(),l_s[30:39].sum(),l_s[40:45].sum()]
labels = ['1~9번', '10~19번', '20~29번', '30~39번','40~45번']

# %%
plt.pie(using,autopct='%.2f%%',startangle=90,labels=labels)
plt.title('로또 번호별 파이 그래프', loc='center', pad=10, fontsize=16, color='g')
plt.axis('equal')
plt.show()

# %%
using = [prize.loc[937]['1등총당첨액'], prize.loc[937]['2등총당첨액'],prize.loc[937]['3등총당첨액'], prize.loc[937]['4등총당첨액'],prize.loc[937]['5등총당첨액']]
labels = ['1등총당첨액', '2등총당첨액', '3등총당첨액', '4등총당첨액','5등총당첨액']

# %%
plt.pie(using,autopct='%.2f%%',startangle=90,labels=labels)
plt.title('로또937회 당첨액 파이그래프', loc='center', pad=10, fontsize=16, color='g')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(5, 5))
using = [prize['1등총당첨액'].mean(),prize['2등총당첨액'].mean(),prize['3등총당첨액'].mean(),prize['4등총당첨액'].mean(),prize['5등총당첨액'].mean()]
labels = ['1등총당첨액', '2등총당첨액', '3등총당첨액', '4등총당첨액','5등총당첨액']
plt.title('역대 로또 당첨액 평균 파이그래프', loc='center', pad=10, fontsize=16, color='g')
plt.pie(using,autopct='%.2f%%',startangle=90,labels=labels)
plt.axis('equal')
plt.show()

# %%
plt.bar('1등 당첨인원수', prize['1등당첨인원수'].mean())
plt.bar('2등 당첨인원수', prize['2등당첨인원수'].mean())
plt.title('역대 로또 당첨 인원 수 평균', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.bar('총 판매금액의 평균', prize['총판매금액'].mean(),color = 'teal')
plt.bar('총 판매금액의 평균', prize['총판매금액'].mean(),color = 'teal')
plt.bar('총당첨액의 평균', (prize['1등총당첨액'].mean()+prize['2등총당첨액'].mean()+prize['3등총당첨액'].mean()+prize['4등총당첨액'].mean()+prize['5등총당첨액'].mean()),color = 'tan')
plt.title('역대 로또 총 판매금액과 총 당첨액 평균  (단위 : 100 억) ', loc='center', pad=10, fontsize=10, color='g')
plt.show()

# %%
plt.figure(figsize=(15, 5))
prize['1등총당첨액'][-10:].plot.barh()
plt.title('로또 1등 총금액 최근 10회간 (단위 : 100 억) ',loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
plt.figure(figsize=(15, 5))
prize['1등총당첨액'][-300:].plot()
plt.show()

# %%
prize[prize['1등총당첨액']==]
# Out:
#      1등총당첨액      2등총당첨액      3등총당첨액      4등총당첨액      5등총당첨액  인당1등당첨액  \
# 회차
# 1         0   143934100   143934000   287695800   401550000        0
# 4         0   211191200   211189600   422381700   523820000        0
# 5         0           0   253419600   506659500   604340000        0
# 7         0   433485000   433485000   866499500  2062590000        0
# 8         0   789330000   789298800  1577829500  2482420000        0
# 9         0  3077826000  3077817600  6154720000  6033750000        0
# 13        0  2599855800  2599830000  5197935600  7267510000        0
# 18        0  2625259500  2625256800  5248834500  6933230000        0
# 24        0  3168426600  3168402500  6333240000  7559050000        0
# 41        0  2297484000  2297470000  4594099500  5837440000        0
# 71        0  2484865600  2484805000  4967161200  6596310000        0
# 289       0  1530280656  1530281212  3060582021  4400515000        0
# 295       0  1637216750  1637217691  3274438256  4751900000        0
# 463       0  2023433208  2023434336  3112550000  5302560000        0
#
#        인당2등당첨액  인당3등당첨액  인당4등당첨액  인당5등당첨액  1등당첨인원수  2등당첨인원수  3등당첨인원수  4등당첨인원수  \
# 회차
# 1    143934100  5140500   113400    10000        0        1       28     2537
# 4    211191200  7282400   152100    10000        0        1       29     2777
# 5            0  6033800   166500    10000        0        0       42     3043
# 7     48165000  1605500    65500    10000        0        9      270    13229
# 8    131555000  2268100   110500    10000        0        6      348    14279
# 9    769456500  8743800   260000    10000        0        4      352    23672
# 13   433309300  5777400   175600    10000        0        6      450    29601
# 18   175017300  3953700   136500    10000        0       15      664    38453
# 24   176023700  3425300   120000    10000        0       18      925    52777
# 41   109404000  3282100   135900    10000        0       21      700    33805
# 71    88745200  3177500   125700    10000        0       28      782    39516
# 289   63761694  1501748    58541     5000        0       24     1019    52281
# 295   62969875  1616207    59131     5000        0       26     1013    55376
# 463   54687384  1613584    50000     5000        0       37     1254    62251
#
#      5등당첨인원수        총판매금액
# 회차
# 1      40155   3681782000
# 4      52382   5271464000
# 5      60434   6277102000
# 7     206259  12794890000
# 8     248242  20751450000
# 9     603375  73624020000
# 13    726751  66532136000
# 18    693323  66371660000
# 24    755905  78486634000
# 41    583744  57624562000
# 71    659631  62889986000
# 289   880103  39406643000
# 295   950380  42248135000
# 463  1060512  49205151000
